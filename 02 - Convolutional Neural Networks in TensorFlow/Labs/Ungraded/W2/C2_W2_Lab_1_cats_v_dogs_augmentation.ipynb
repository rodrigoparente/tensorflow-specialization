# %% [markdown]
# # Ungraded Lab: Data Augmentation
#
# In the previous lessons, you saw that having a high training accuracy does not automatically mean having a good predictive model. It can still perform poorly on new data because it has overfit to the training set. In this lab, you will see how to avoid that using _data augmentation_. This increases the amount of training data by modifying the existing training data's properties. For example, in image data, you can apply different preprocessing techniques such as rotate, flip, shear, or zoom on your existing images so you can simulate other data that the model should also learn from. This way, the model would see more variety in the images during training so it will infer better on new, previously unseen data.
#
# Let's see how you can do this in the following sections.

# %% [markdown]
# ## Baseline Performance
#
# You will start with a model that's very effective at learning `Cats vs Dogs` without data augmentation. It's similar to the previous models that you have used. Note that there are four convolutional layers with 32, 64, 128 and 128 convolutions respectively. The code is basically the same from the previous lab so we won't go over the details step by step since you've already seen it before.

# %%
# First import the necessary libraries
import os
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# 2024-10-04 15:49:10.520944: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-04 15:49:10.740634: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-04 15:49:10.825561: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-04 15:49:10.849901: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-04 15:49:11.014121: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-04 15:49:12.271333: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
BASE_DIR = './cats_and_dogs_filtered'

train_dir = os.path.join(BASE_DIR, 'train')
validation_dir = os.path.join(BASE_DIR, 'validation')

# Directory with training cat/dog pictures
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with validation cat/dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

print(f"Contents of base directory: {os.listdir(BASE_DIR)}")

print(f"\nContents of train directory: {os.listdir(train_dir)}")

print(f"\nContents of validation directory: {os.listdir(validation_dir)}")
# Out:
# Contents of base directory: ['validation', 'train']
#
# Contents of train directory: ['dogs', 'cats']
#
# Contents of validation directory: ['dogs', 'cats']

# %% [markdown]
# You will place the model creation inside a function so you can easily initialize a new one when you use data augmentation later in this notebook.

# %%
def create_model():
    '''Creates a CNN with 4 convolutional layers'''
    model = tf.keras.models.Sequential([
        tf.keras.Input(shape=(150, 150, 3)),
        tf.keras.layers.Rescaling(1./255),
        tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2, 2),
        tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    return model

# %% [markdown]
# You will preprocess the training and validation datasets as usual.

# %%
# Instantiate the training dataset
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(150, 150),
    batch_size=20,
    label_mode='binary'
    )

# Instantiate the validation dataset
validation_dataset = tf.keras.utils.image_dataset_from_directory(
    validation_dir,
    image_size=(150, 150),
    batch_size=20,
    label_mode='binary'
    )

# Optimize the datasets for training
SHUFFLE_BUFFER_SIZE = 1000
PREFETCH_BUFFER_SIZE = tf.data.AUTOTUNE

train_dataset_final = (train_dataset
                       .cache()
                       .shuffle(SHUFFLE_BUFFER_SIZE)
                       .prefetch(PREFETCH_BUFFER_SIZE)
                       )

validation_dataset_final = (validation_dataset
                            .cache()
                            .prefetch(PREFETCH_BUFFER_SIZE)
                            )
# Out:
# Found 2000 files belonging to 2 classes.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728067763.022096  207354 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1728067763.211764  207354 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1728067763.211831  207354 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1728067763.215594  207354 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1728067763.215631  207354 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1728067763.215645  207354 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1728067763.976227  207354 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1728067763.976363  207354 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-04 15:49:23.976379: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1728067763.976418  207354 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-04 15:49:23.977037: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3586 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Found 1000 files belonging to 2 classes.

# %% [markdown]
# You will train only for 20 epochs to save time but feel free to increase this if you want.

# %%
# Constant for epochs
EPOCHS = 20

# Create a new model
model = create_model()

# Setup the training parameters
model.compile(loss='binary_crossentropy',
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
              metrics=['accuracy'])

# Train the model
history = model.fit(
      train_dataset_final,
      epochs=EPOCHS,
      validation_data=validation_dataset_final,
      verbose=2)
# Out:
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728067777.422142  207548 service.cc:146] XLA service 0x7f18fc003c90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728067777.422200  207548 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2024-10-04 15:49:37.463158: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-04 15:49:37.633053: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# I0000 00:00:1728067781.204374  207548 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 100/100 - 7s - 71ms/step - accuracy: 0.5110 - loss: 0.6921 - val_accuracy: 0.5000 - val_loss: 0.6879
# Epoch 2/20
# 100/100 - 2s - 16ms/step - accuracy: 0.5755 - loss: 0.6794 - val_accuracy: 0.6030 - val_loss: 0.6632
# Epoch 3/20
# 100/100 - 2s - 16ms/step - accuracy: 0.6000 - loss: 0.6664 - val_accuracy: 0.5850 - val_loss: 0.6586
# Epoch 4/20
# 100/100 - 2s - 16ms/step - accuracy: 0.6395 - loss: 0.6422 - val_accuracy: 0.6500 - val_loss: 0.6315
# Epoch 5/20
# 100/100 - 2s - 16ms/step - accuracy: 0.6690 - loss: 0.6181 - val_accuracy: 0.6670 - val_loss: 0.6135
# Epoch 6/20
# 100/100 - 2s - 16ms/step - accuracy: 0.6870 - loss: 0.5870 - val_accuracy: 0.6960 - val_loss: 0.5794
# Epoch 7/20
# 100/100 - 2s - 16ms/step - accuracy: 0.7200 - loss: 0.5594 - val_accuracy: 0.6700 - val_loss: 0.6272
# Epoch 8/20
# 100/100 - 2s - 17ms/step - accuracy: 0.7460 - loss: 0.5308 - val_accuracy: 0.7090 - val_loss: 0.5561
# Epoch 9/20
# 100/100 - 2s - 17ms/step - accuracy: 0.7470 - loss: 0.5114 - val_accuracy: 0.7240 - val_loss: 0.5469
# Epoch 10/20
# 100/100 - 2s - 17ms/step - accuracy: 0.7670 - loss: 0.4850 - val_accuracy: 0.7180 - val_loss: 0.5526
# Epoch 11/20
# 100/100 - 2s - 17ms/step - accuracy: 0.7780 - loss: 0.4678 - val_accuracy: 0.7290 - val_loss: 0.5616
# Epoch 12/20
# 100/100 - 2s - 17ms/step - accuracy: 0.7820 - loss: 0.4458 - val_accuracy: 0.7390 - val_loss: 0.5296
# Epoch 13/20
# 100/100 - 2s - 17ms/step - accuracy: 0.8110 - loss: 0.4177 - val_accuracy: 0.7260 - val_loss: 0.5508
# Epoch 14/20
# 100/100 - 2s - 17ms/step - accuracy: 0.8225 - loss: 0.4029 - val_accuracy: 0.7390 - val_loss: 0.5226
# Epoch 15/20
# 100/100 - 2s - 17ms/step - accuracy: 0.8350 - loss: 0.3703 - val_accuracy: 0.7390 - val_loss: 0.5240
# Epoch 16/20
# 100/100 - 0s - 3ms/step - accuracy: 0.8515 - loss: 0.3476 - val_accuracy: 0.7460 - val_loss: 0.5294
# Epoch 17/20
# 100/100 - 2s - 17ms/step - accuracy: 0.8565 - loss: 0.3290 - val_accuracy: 0.7380 - val_loss: 0.5552
# Epoch 18/20
# 100/100 - 2s - 17ms/step - accuracy: 0.8735 - loss: 0.3043 - val_accuracy: 0.7550 - val_loss: 0.5173
# Epoch 19/20
# 100/100 - 2s - 17ms/step - accuracy: 0.8855 - loss: 0.2903 - val_accuracy: 0.7520 - val_loss: 0.5786
# Epoch 20/20
# 100/100 - 2s - 17ms/step - accuracy: 0.8905 - loss: 0.2664 - val_accuracy: 0.7420 - val_loss: 0.5536

# %% [markdown]
# You will then visualize the loss and accuracy with respect to the training and validation set. You will again use a convenience function so it can be reused later. This function accepts a [History](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History) object which contains the results of the `fit()` method you ran above.

# %%
def plot_loss_acc(history):
    '''Plots the training and validation loss and accuracy from a history object'''
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    fig, ax = plt.subplots(1,2, figsize=(12, 6))
    ax[0].plot(epochs, acc, 'bo', label='Training accuracy')
    ax[0].plot(epochs, val_acc, 'b', label='Validation accuracy')
    ax[0].set_title('Training and validation accuracy')
    ax[0].set_xlabel('epochs')
    ax[0].set_ylabel('accuracy')
    ax[0].legend()

    ax[1].plot(epochs, loss, 'bo', label='Training Loss')
    ax[1].plot(epochs, val_loss, 'b', label='Validation Loss')
    ax[1].set_title('Training and validation loss')
    ax[1].set_xlabel('epochs')
    ax[1].set_ylabel('loss')
    ax[1].legend()

    plt.show()

# %%
# Plot training results
plot_loss_acc(history)

# %% [markdown]
# From the results above, you'll see the training accuracy is more than 90%, and the validation accuracy is in the 70%-80% range. This is a great example of _overfitting_ -- which in short means that it can do very well with images it has seen before, but not so well with images it hasn't.

# %% [markdown]
# ## Data augmentation
#
# One simple method to avoid overfitting is to augment the images. If you think about it, most pictures of a cat are very similar -- the ears are at the top, the eyes are below the ears etc. Things like the distance between the eyes and ears will always be quite similar too.
#
# What if you tweak with the images a bit -- rotate the image, squash it, etc.  That's what image augmentation is all about.
#
# To do that, you will build a data augmentation model with [preprocessing layers for image augmentation](https://www.tensorflow.org/guide/keras/preprocessing_layers#image_data_augmentation). This will transform the data during training to introduce variations of the same image. Let's quickly go over the layers you will use in this exercise.
#
# * [RandomFlip](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomFlip) is for randomly flipping the images horizontally, vertically, or both.
# * [RandomRotation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomRotation) rotates the image by an angle within a given range.
# * [RandomTranslation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomTranslation) shifts pictures vertically and horizontally.
# * [RandomZoom](https://www.tensorflow.org/api_docs/python/tf/keras/layers/RandomZoom) zooms into or out of the images.
#
# In addition, some of these layers have a `fill_mode` parameter. This is the strategy used for filling newly created pixels, which can appear after a rotation or a width/height shift.
#
# The code below will create this model with some set parameters. After you complete this lab, feel free to modify these and see the impact on the results.

# %%
# Define fill mode.
FILL_MODE = 'nearest'

# Create the augmentation model.
data_augmentation = tf.keras.Sequential([
    # Specify the input shape.
    tf.keras.Input(shape=(150,150,3)),
    # Add the augmentation layers
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2, fill_mode=FILL_MODE),
    tf.keras.layers.RandomTranslation(0.2,0.2, fill_mode=FILL_MODE),
    tf.keras.layers.RandomZoom(0.2, fill_mode=FILL_MODE)
    ])

# %% [markdown]
# You will define a utility function that lets you preview how the transformed images look like. It will take in a sample image, then output a given number of augmented images using the model you defined above.

# %%
def demo_augmentation(sample_image, model, num_aug):
    '''Takes a single image array, then uses a model to generate num_aug transformations'''

    # Instantiate preview list
    image_preview = []

    # Convert input image to a PIL image instance
    sample_image_pil = tf.keras.utils.array_to_img(sample_image)

    # Append the result to the list
    image_preview.append(sample_image_pil)

    # Apply the image augmentation and append the results to the list
    for i in range(num_aug):
        sample_image_aug = model(tf.expand_dims(sample_image, axis=0))
        sample_image_aug_pil = tf.keras.utils.array_to_img(tf.squeeze(sample_image_aug))
        image_preview.append(sample_image_aug_pil)

    # Instantiate a subplot
    fig, axes = plt.subplots(1, num_aug + 1, figsize=(12, 12))

    # Preview the images.
    for index, ax in enumerate(axes):
        ax.imshow(image_preview[index])
        ax.set_axis_off()

        if index == 0:
            ax.set_title('original')
        else:
            ax.set_title(f'augment {index}')

# %% [markdown]
# Now get some images from the dataset.

# %%
# Get a batch of images
sample_batch = list(train_dataset.take(1))[0][0]
print(f'images per batch: {len(sample_batch)}')
# Out:
# images per batch: 20
# 2024-10-04 15:55:48.844091: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# This will show sample transformations for the first 4 images of the sample batch. Notice that each call of the `data_augmentation` model yields a different output. It's like adding more images to your dataset without you having to collect them manually.

# %%
NUM_AUG = 4

# Apply the transformations to the first 4 images
demo_augmentation(sample_batch[0], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[1], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[2], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[3], data_augmentation, NUM_AUG)

# Uncomment the line below to delete the variable to free up some memory
# del sample_batch

# %% [markdown]
# Now that you see what the preprocessing layers do, you can prepend these to the base model so it can generate transformed images to the base model. Do note that these layers are only active while training. They are automatically disabled during prediction and evaluation.

# %%
# Instantiate the base model
model_without_aug = create_model()

# Prepend the data augmentation layers to the base model
model_with_aug = tf.keras.models.Sequential([
    data_augmentation,
    model_without_aug
])

# Compile the model
model_with_aug.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
    metrics=['accuracy'])

# %% [markdown]
# Because you now have virtually more data, it will also take the model more time to learn the relevant features. Without data augmentation, your model already started overfitting to the training set within 20 epochs. Try training this model for 80 epochs and observe the results.

# %%
EPOCHS=80

# Train the new model
history_with_aug = model_with_aug.fit(
      train_dataset_final,
      epochs=EPOCHS,
      validation_data=validation_dataset_final,
      verbose=2)
# Out:
# Epoch 1/80
# W0000 00:00:1728068231.021653  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.046392  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.059583  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.073050  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.086637  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.099199  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.113147  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.125706  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.139693  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.155385  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.169133  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.183186  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.206714  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.230290  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.253877  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.277565  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.285153  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.290277  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.295247  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.300536  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.305565  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.308186  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.311350  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.314524  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.319949  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.325106  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.328428  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.331744  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.335268  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.338581  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.345191  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.349019  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.352589  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.357528  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.361677  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.369073  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.454589  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.456415  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.458204  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.459726  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.461215  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.463129  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.465003  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.466523  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.468032  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.469765  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.471653  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.473374  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.474935  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.476565  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.478217  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.479923  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.481600  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.483466  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.485333  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.487045  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.488678  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.490635  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.492093  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.494337  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.496534  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.498777  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.501054  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.503105  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.505368  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.507650  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.512121  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.514033  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.516148  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.518408  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.520609  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.525259  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.527491  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.530003  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.532217  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.534437  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.548730  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.550659  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.552110  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.553600  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.555043  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.556553  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.557987  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.559540  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.561240  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.562806  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.564369  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.565789  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.567374  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.568763  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.570265  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.571902  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.573410  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.574947  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.576436  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.578008  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.579660  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.581141  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.582661  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.584114  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.587439  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.588964  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.590584  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.592462  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.594029  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.595552  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.597130  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.598764  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.600321  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.601909  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.603503  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.605182  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.606793  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.608548  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.610242  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.611990  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.625780  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.627482  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.628787  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.630117  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.631367  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.632739  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.634026  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.635373  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.636616  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.637839  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.639123  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.640252  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.641380  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.642487  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.643639  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.644829  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.646018  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.647255  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.648417  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.649610  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.650780  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.651898  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.653052  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.654184  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.655373  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.656546  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.657750  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.658974  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.660310  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.661571  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.662786  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.664081  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.665411  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.666862  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.668693  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.670227  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.671497  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068231.672689  207546 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.017995  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.019446  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.020554  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.021679  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.022768  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.023881  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.024979  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.026055  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.027109  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.028172  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.029270  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.030350  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.031479  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.032570  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.033807  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.034887  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.036010  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.037222  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.038406  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.039676  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.040883  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.042597  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.043868  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.045152  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.056350  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.057755  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.059054  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.060299  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.061527  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.062726  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.063987  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.065289  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.066666  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.067905  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.069089  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.070507  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.071880  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.073252  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.074590  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.075885  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.077228  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.078555  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.079818  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.080953  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.082276  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.083663  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.085032  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.086382  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.087609  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.089433  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.091092  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.092532  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.094004  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.096072  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.097820  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.160006  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.161778  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.163394  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.165071  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.166481  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.167915  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.169329  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.170720  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.172123  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.173517  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.175211  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.176912  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.178576  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.180248  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.181883  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.183414  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.185352  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.187195  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.188904  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.190581  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.192355  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.195193  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.197700  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.199686  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.201963  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.204173  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.212241  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.214223  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.215902  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.217499  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.219247  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.220937  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.222651  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.224290  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.225972  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.227854  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.229661  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.231813  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.233617  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.235433  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.237886  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.239884  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.242165  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.244248  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.245946  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.248055  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.250156  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.251898  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.253810  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.255883  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.257564  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.259723  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.261839  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.264387  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.266747  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.277367  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.279196  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.281438  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.283682  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.286057  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.288384  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.290795  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.292751  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.295105  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.297599  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.300642  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.303696  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.306740  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.309234  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.311951  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.315002  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.318169  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.320355  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.323933  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.326986  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.330320  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.334969  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.338431  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.341188  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.343860  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.348037  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.352379  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.369963  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.372282  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.374612  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.377076  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.380160  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.382493  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.384692  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.387767  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.390550  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.392730  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.394769  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.397588  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.400157  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.402327  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.406630  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.410373  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.413046  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.417158  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.419956  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.424031  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.427577  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.429681  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.433541  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.437435  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.442160  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.446566  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.450684  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.452714  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.460899  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.498831  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.500972  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.502785  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.504612  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.507197  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.509313  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.512229  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.514566  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.517598  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.520605  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.523453  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.526305  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.528951  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.533218  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.536409  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.539583  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.543579  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.546809  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.549034  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.551381  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.556829  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.561794  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.565814  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.570998  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.577929  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068232.587626  207549 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.794833  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.802584  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.804173  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.806145  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.808060  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.809318  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.810494  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.811686  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.812855  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.854295  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.856632  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.858925  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.862523  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.865142  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.867407  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.869805  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.872187  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.874543  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.877506  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.880649  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.883610  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.886759  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.889982  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.893845  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.897257  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.901050  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.905741  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.909411  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.914159  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.918879  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.923641  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.928730  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.959658  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.961543  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.963077  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.964619  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.966166  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.967697  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.969438  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.971193  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.972679  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.974500  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.976377  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.978331  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.980166  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.981876  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.983788  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.985505  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.987571  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.989234  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.991040  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.993048  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068234.995182  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# ...
# W0000 00:00:1728068235.088762  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.090300  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.091907  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.093413  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.094919  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.096540  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.098175  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.100100  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.101768  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.103755  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.105541  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.107539  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.109114  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.110629  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.112431  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.114257  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.116202  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.118418  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.120439  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.122649  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.136947  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.138484  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.139707  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.140976  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.142336  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.143631  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.144896  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.146220  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.147496  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.148811  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.150096  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.151260  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.152422  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.153605  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.154822  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.155976  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.157227  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.158449  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.159631  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.160766  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.161929  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.163082  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.164282  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.165427  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.166605  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.167840  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.169054  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.170187  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.171334  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.172501  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.173691  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.174953  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.176483  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.177856  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.179351  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.180795  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.182087  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728068235.183560  207545 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 100/100 - 5s - 54ms/step - accuracy: 0.5065 - loss: 0.6937 - val_accuracy: 0.5000 - val_loss: 0.6877
# Epoch 2/80
# 100/100 - 2s - 24ms/step - accuracy: 0.5535 - loss: 0.6867 - val_accuracy: 0.5970 - val_loss: 0.6733
# Epoch 3/80
# 100/100 - 2s - 24ms/step - accuracy: 0.5620 - loss: 0.6781 - val_accuracy: 0.5960 - val_loss: 0.6595
# Epoch 4/80
# 100/100 - 3s - 26ms/step - accuracy: 0.5800 - loss: 0.6752 - val_accuracy: 0.6110 - val_loss: 0.6603
# Epoch 5/80
# 100/100 - 2s - 24ms/step - accuracy: 0.5920 - loss: 0.6665 - val_accuracy: 0.5490 - val_loss: 0.6824
# Epoch 6/80
# 100/100 - 2s - 24ms/step - accuracy: 0.6080 - loss: 0.6546 - val_accuracy: 0.5700 - val_loss: 0.6827
# Epoch 7/80
# 100/100 - 2s - 24ms/step - accuracy: 0.6230 - loss: 0.6441 - val_accuracy: 0.6290 - val_loss: 0.6409
# Epoch 8/80
# 100/100 - 2s - 24ms/step - accuracy: 0.6365 - loss: 0.6345 - val_accuracy: 0.6510 - val_loss: 0.6092
# Epoch 9/80
# 100/100 - 1s - 10ms/step - accuracy: 0.6445 - loss: 0.6280 - val_accuracy: 0.6580 - val_loss: 0.6177
# Epoch 10/80
# 100/100 - 2s - 24ms/step - accuracy: 0.6545 - loss: 0.6163 - val_accuracy: 0.6660 - val_loss: 0.6032
# Epoch 11/80
# 100/100 - 2s - 24ms/step - accuracy: 0.6555 - loss: 0.6165 - val_accuracy: 0.5870 - val_loss: 0.6878
# Epoch 12/80
# 100/100 - 2s - 24ms/step - accuracy: 0.6625 - loss: 0.6063 - val_accuracy: 0.6490 - val_loss: 0.6118
# Epoch 13/80
# 100/100 - 2s - 24ms/step - accuracy: 0.6735 - loss: 0.6031 - val_accuracy: 0.6500 - val_loss: 0.6020
# Epoch 14/80
# 100/100 - 2s - 24ms/step - accuracy: 0.6725 - loss: 0.6003 - val_accuracy: 0.6610 - val_loss: 0.5902
# Epoch 15/80
# 100/100 - 2s - 24ms/step - accuracy: 0.6800 - loss: 0.5908 - val_accuracy: 0.6480 - val_loss: 0.6291
# Epoch 16/80
# 100/100 - 2s - 24ms/step - accuracy: 0.6840 - loss: 0.5876 - val_accuracy: 0.7000 - val_loss: 0.5662
# Epoch 17/80
# 100/100 - 2s - 24ms/step - accuracy: 0.6855 - loss: 0.5859 - val_accuracy: 0.6380 - val_loss: 0.6110
# Epoch 18/80
# 100/100 - 2s - 24ms/step - accuracy: 0.6870 - loss: 0.5886 - val_accuracy: 0.6630 - val_loss: 0.6044
# Epoch 19/80
# 100/100 - 2s - 24ms/step - accuracy: 0.6885 - loss: 0.5867 - val_accuracy: 0.7120 - val_loss: 0.5449
# Epoch 20/80
# 100/100 - 2s - 24ms/step - accuracy: 0.6835 - loss: 0.5856 - val_accuracy: 0.7110 - val_loss: 0.5484
# Epoch 21/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7060 - loss: 0.5696 - val_accuracy: 0.7080 - val_loss: 0.5388
# Epoch 22/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7060 - loss: 0.5581 - val_accuracy: 0.7310 - val_loss: 0.5332
# Epoch 23/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7095 - loss: 0.5655 - val_accuracy: 0.7110 - val_loss: 0.5375
# Epoch 24/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7015 - loss: 0.5663 - val_accuracy: 0.7200 - val_loss: 0.5356
# Epoch 25/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7120 - loss: 0.5583 - val_accuracy: 0.6460 - val_loss: 0.6362
# Epoch 26/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7205 - loss: 0.5547 - val_accuracy: 0.7130 - val_loss: 0.5348
# Epoch 27/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7185 - loss: 0.5552 - val_accuracy: 0.6370 - val_loss: 0.6789
# Epoch 28/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7170 - loss: 0.5508 - val_accuracy: 0.7240 - val_loss: 0.5312
# Epoch 29/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7220 - loss: 0.5462 - val_accuracy: 0.7250 - val_loss: 0.5204
# Epoch 30/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7235 - loss: 0.5397 - val_accuracy: 0.6850 - val_loss: 0.6061
# Epoch 31/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7085 - loss: 0.5505 - val_accuracy: 0.7150 - val_loss: 0.5301
# Epoch 32/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7320 - loss: 0.5321 - val_accuracy: 0.7300 - val_loss: 0.5154
# Epoch 33/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7215 - loss: 0.5440 - val_accuracy: 0.7260 - val_loss: 0.5212
# Epoch 34/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7325 - loss: 0.5393 - val_accuracy: 0.7140 - val_loss: 0.5280
# Epoch 35/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7250 - loss: 0.5397 - val_accuracy: 0.7280 - val_loss: 0.5183
# Epoch 36/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7315 - loss: 0.5398 - val_accuracy: 0.7260 - val_loss: 0.5245
# Epoch 37/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7420 - loss: 0.5351 - val_accuracy: 0.7390 - val_loss: 0.5139
# Epoch 38/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7365 - loss: 0.5341 - val_accuracy: 0.7420 - val_loss: 0.5097
# Epoch 39/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7380 - loss: 0.5266 - val_accuracy: 0.7280 - val_loss: 0.5116
# Epoch 40/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7410 - loss: 0.5210 - val_accuracy: 0.7390 - val_loss: 0.5016
# Epoch 41/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7345 - loss: 0.5266 - val_accuracy: 0.7220 - val_loss: 0.5484
# Epoch 42/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7365 - loss: 0.5178 - val_accuracy: 0.7510 - val_loss: 0.4926
# Epoch 43/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7500 - loss: 0.5267 - val_accuracy: 0.7380 - val_loss: 0.5250
# Epoch 44/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7385 - loss: 0.5198 - val_accuracy: 0.7380 - val_loss: 0.5033
# Epoch 45/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7355 - loss: 0.5216 - val_accuracy: 0.7450 - val_loss: 0.4915
# Epoch 46/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7480 - loss: 0.5125 - val_accuracy: 0.7180 - val_loss: 0.5371
# Epoch 47/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7495 - loss: 0.5210 - val_accuracy: 0.7540 - val_loss: 0.4948
# Epoch 48/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7455 - loss: 0.5102 - val_accuracy: 0.7460 - val_loss: 0.4892
# Epoch 49/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7420 - loss: 0.5158 - val_accuracy: 0.7580 - val_loss: 0.4842
# Epoch 50/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7510 - loss: 0.4992 - val_accuracy: 0.7410 - val_loss: 0.5036
# Epoch 51/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7445 - loss: 0.5123 - val_accuracy: 0.7560 - val_loss: 0.4896
# Epoch 52/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7535 - loss: 0.5066 - val_accuracy: 0.7530 - val_loss: 0.4912
# Epoch 53/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7530 - loss: 0.5002 - val_accuracy: 0.7500 - val_loss: 0.5003
# Epoch 54/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7500 - loss: 0.5046 - val_accuracy: 0.7440 - val_loss: 0.5024
# Epoch 55/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7705 - loss: 0.4875 - val_accuracy: 0.7420 - val_loss: 0.5066
# Epoch 56/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7630 - loss: 0.4927 - val_accuracy: 0.7590 - val_loss: 0.4951
# Epoch 57/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7555 - loss: 0.4953 - val_accuracy: 0.7460 - val_loss: 0.5054
# Epoch 58/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7690 - loss: 0.4936 - val_accuracy: 0.7390 - val_loss: 0.5002
# Epoch 59/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7535 - loss: 0.4948 - val_accuracy: 0.7360 - val_loss: 0.4865
# Epoch 60/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7665 - loss: 0.4827 - val_accuracy: 0.7330 - val_loss: 0.5064
# Epoch 61/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7655 - loss: 0.4808 - val_accuracy: 0.7530 - val_loss: 0.4887
# Epoch 62/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7585 - loss: 0.4883 - val_accuracy: 0.7550 - val_loss: 0.4881
# Epoch 63/80
# 100/100 - 1s - 10ms/step - accuracy: 0.7690 - loss: 0.4872 - val_accuracy: 0.7510 - val_loss: 0.4895
# Epoch 64/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7565 - loss: 0.4975 - val_accuracy: 0.7540 - val_loss: 0.5017
# Epoch 65/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7435 - loss: 0.5012 - val_accuracy: 0.7380 - val_loss: 0.5192
# Epoch 66/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7650 - loss: 0.4878 - val_accuracy: 0.7650 - val_loss: 0.4749
# Epoch 67/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7580 - loss: 0.4905 - val_accuracy: 0.7490 - val_loss: 0.4924
# Epoch 68/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7730 - loss: 0.4779 - val_accuracy: 0.7500 - val_loss: 0.4875
# Epoch 69/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7780 - loss: 0.4737 - val_accuracy: 0.7610 - val_loss: 0.4728
# Epoch 70/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7695 - loss: 0.4778 - val_accuracy: 0.7510 - val_loss: 0.4854
# Epoch 71/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7735 - loss: 0.4768 - val_accuracy: 0.7380 - val_loss: 0.5017
# Epoch 72/80
# 100/100 - 2s - 25ms/step - accuracy: 0.7725 - loss: 0.4751 - val_accuracy: 0.7480 - val_loss: 0.4961
# Epoch 73/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7695 - loss: 0.4726 - val_accuracy: 0.7650 - val_loss: 0.4751
# Epoch 74/80
# 100/100 - 2s - 25ms/step - accuracy: 0.7795 - loss: 0.4609 - val_accuracy: 0.7610 - val_loss: 0.4822
# Epoch 75/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7805 - loss: 0.4779 - val_accuracy: 0.7520 - val_loss: 0.4817
# Epoch 76/80
# 100/100 - 1s - 11ms/step - accuracy: 0.7775 - loss: 0.4684 - val_accuracy: 0.7650 - val_loss: 0.4740
# Epoch 77/80
# 100/100 - 2s - 25ms/step - accuracy: 0.7670 - loss: 0.4741 - val_accuracy: 0.7580 - val_loss: 0.4734
# Epoch 78/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7835 - loss: 0.4602 - val_accuracy: 0.7560 - val_loss: 0.5202
# Epoch 79/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7870 - loss: 0.4602 - val_accuracy: 0.7450 - val_loss: 0.5063
# Epoch 80/80
# 100/100 - 2s - 24ms/step - accuracy: 0.7875 - loss: 0.4480 - val_accuracy: 0.7440 - val_loss: 0.5205

# %%
# Plot the results of training with data augmentation
plot_loss_acc(history_with_aug)

# %% [markdown]
# As you can see, the training accuracy has gone down compared to the baseline. This is expected because (as a result of data augmentation) there are more variety in the images so the model will need more runs to learn from them. The good thing is the validation accuracy is no longer stalling and is more in line with the training results. This means that the model is now performing better on unseen data.

# %% [markdown]
# ## Wrap Up
#
# This exercise showed a simple trick to avoid overfitting. You can improve your baseline results by simply tweaking the same images you have already. The image augmentation preprocessing layers will do just that. Try to modify the values in the augmentation model and see what results you get. You can also add other preprocessing layers for random contrast, brightness, or cropping.
#
# Take note that this will not work for all cases. In the next lesson, Laurence will show a scenario where data augmentation will not help improve your validation accuracy.
#
# Before going back to the classroom, run the cell below to free up resources for the next lab. You might see a pop-up about restarting the kernel afterwards. You can safely ignore it and just press Ok. You can then close this lab, then go back to the classroom for the next lecture. See you there!
